# %%
import pandas as pd
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tag.perceptron import PerceptronTagger
from nltk.corpus import stopwords
import re

# %%
def remove_stops(data_str):
    # expects a string
    stops = set(stopwords.words("english"))
    list_pos = 0
    cleaned_str = ''
    text = data_str.split()
    for word in text:
        if word not in stops:
            # rebuild cleaned_str
            if list_pos == 0:
                cleaned_str = word
            else:
                cleaned_str = cleaned_str + ' ' + word
            list_pos += 1
    return cleaned_str

def tag_and_remove(data_str):
    cleaned_str = ' '
    # noun tags
    nn_tags = ['NN', 'NNP', 'NNP', 'NNPS', 'NNS']
    # adjectives
    jj_tags = ['JJ', 'JJR', 'JJS']
    # verbs
    vb_tags = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
    #adverbs
    av_tags = ['RB','RBR','RBS']
    nltk_tags = nn_tags + jj_tags + vb_tags + av_tags

    # break string into 'words'
    text = data_str.split()

    # tag the text and keep only those with the right tags
    #tagged_text = pos_tag(text)
    tagged_text = tagger.tag(text)
    for tagged_word in tagged_text:
        if tagged_word[1] in nltk_tags:
            cleaned_str += tagged_word[0] + ' '

    return cleaned_str

def lemmatize(data_str):
    # expects a string
    list_pos = 0
    cleaned_str = ''
    lmtzr = WordNetLemmatizer()
    text = data_str.split()
    #tagged_words = pos_tag(text)
    tagged_words = tagger.tag(text)
    for word in tagged_words:
        if 'v' in word[1].lower():
            lemma = lmtzr.lemmatize(word[0], pos='v')
        elif 'r' in word[1].lower():
            lemma = lmtzr.lemmatize(word[0], pos='r')
        elif 'a' in word[1].lower():
            lemma = lmtzr.lemmatize(word[0], pos='a')
        else:
            lemma = lmtzr.lemmatize(word[0], pos='n')
        if list_pos == 0:
            cleaned_str = lemma
        else:
            cleaned_str = cleaned_str + ' ' + lemma
        list_pos += 1
    return cleaned_str

# %%
hockey = pd.read_csv('additional_corrections.csv')

# %%
hockey.head()
# Out:
#    Unnamed: 0                                            tweet_1       team
# 0           0   time retweet and follow to enter if buch scor...    ['nyr']
# 1           1  which canadiens are untouchable beside mete price   ['habs']
# 2           2                                lets do that hockey   ['wild']
# 3           3                                        ed  belfour  ['stars']
# 4           4             happy birthday ryan grim reaper reaves   ['pens']

# %%
hockey.drop('Unnamed: 0', 1, inplace=True)

# %%
hockey.head()
# Out:
#                                              tweet_1       team
# 0   time retweet and follow to enter if buch scor...    ['nyr']
# 1  which canadiens are untouchable beside mete price   ['habs']
# 2                                lets do that hockey   ['wild']
# 3                                        ed  belfour  ['stars']
# 4             happy birthday ryan grim reaper reaves   ['pens']

# %%
hockey['tweet_1'] = hockey['tweet_1'].astype('str')

# %%
hockey['stop_text'] = hockey['tweet_1'].apply(remove_stops)

# %%
hockey[['tweet_1','stop_text']]
# 4                  happy birthday ryan grim reaper reaves
# 5       big weekend minnesota sport fans today st clou...
# 6                  learn play program back season details
# 7                      happy best penguins fans know cred
# 8       g canucks oilers first saturday without red fi...
# 9           game day avalanche colorado pm pregame report
# 10              pretty much thing find interesting hockey
# 11      stats goal wild bill becomes first western con...
# 12           last nights ot thriller vegas golden knights
# 13                                           welcome back
# 14          game day avalanche colorado pm pregame report
# 15      limited lower level inventory remains tomorrow...
# 16      could imagine goalie time equipment today goal...
# 17      bobby hull still undecided wearing helmet may ...
# 18                             hurricanes tonight preview
# 19      cooper hiccups question theyre less think that...
# 20                                         love andy much
# 21                    still havent heard code anyone else
# 22      today ryan reaves birthday thank video wish ha...
# 23      things tonights game maple leafs including tho...
# 24      opening game tradition since loud catches th h...
# 25      make pick roulette using either chance win awe...
# 26      today ryan reaves birthday thank video wish ha...
# 27      confronted jason chimera last week snarled lik...
# 28        optional skate karlsson ice colin white arrived
# 29      game day montreal face canadiens tonight pm et...
# ...                                                   ...
# 448259         beau another steal barzal eberle top shelf
# 448260  brayden schenn records th game winning goal se...
# 448261  tampa bay lightning philadelphia flyers photo ...
# 448262         beau another steal barzal eberle top shelf
# 448263                                               mood
# 448264  mcdonagh became first defenseman registered tw...
# 448265         beau another steal barzal eberle top shelf
# 448266                                           bad news
# 448267              shares special guest appearance watch
# 448268         beau another steal barzal eberle top shelf
# 448269  tonight would like welcome nonprofit night hon...
# 448270  carter hutton gaa svpercent one shutout last n...
# 448271                      asked attend weekend accepted
# 448272  pass mats zuccarello jt miller buries give ran...
# 448273  speculators start engines writes fans going re...
# 448274                      asked attend weekend accepted
# 448275  metro standings washington capitals points gam...
# 448276  quick thoughts tonight going weekend frustrati...
# 448277                                                nan
# 448278                                       brace go bar
# 448279  win win get pack timbits purchase coffee parti...
# 448280  honour chris neil year nhl career ottawa playi...
# 448281  hab listen podcast drouin spark pacioretty fir...
# 448282                     three game vs vegas jaro halak
# 448283  wild goal nullified due goalie interference ko...
# 448284  wild goal nullified due goalie interference ko...
# 448285                 full list teams lost season series
# 448286  honour chris neil year nhl career ottawa playi...
# 448287  trade evander kane thomas vanek much better op...
# 448288  fan traveled nashville see play find game new ...
#
# [448289 rows x 2 columns]

# %%
tagger = PerceptronTagger()
hockey['tag_text'] = hockey['stop_text'].apply(tag_and_remove)

# %%
hockey['lemm_text'] = hockey['tag_text'].apply(lemmatize)

# %%
hockey[['tweet_1','team']].to_csv('no_removal_stops_tweets.csv')

# %%
hockey[['stop_text','team']].to_csv('removal_stops_tweets.csv')

# %%
hockey[['lemm_text','team']].to_csv('lemmatized_tweets.csv')
