# %%
import pandas as pd
import re
import numpy as np

# %%
col_dict = {"team": lambda x: x.strip("[]").replace('\'', '').split(", ")}
hockey = pd.read_csv('/Users/matthewcassi/Documents/nhl_sentiment_working/no_num_hash_mentions/cleaning/no_hash_url_mentions.csv', converters=col_dict)
hockey = hockey.drop('Unnamed: 0', 1)

# %%
hockey.head()
# Out:
#             created_at  hour  \
# 0  2018-01-20 15:34:25    15
# 1  2018-01-20 15:34:27    15
# 2  2018-01-20 15:34:28    15
# 3  2018-01-20 15:34:32    15
# 4  2018-01-20 15:34:33    15
#
#                                              tweet_1     team
# 0   time retweet and follow to enter if buch scor...    [nyr]
# 1  which canadiens are untouchable beside mete price   [habs]
# 2                                lets do that hockey   [wild]
# 3                                 ed friggin belfour  [stars]
# 4             happy birthday ryan grim reaper reaves   [pens]

# %%
hockey.drop('created_at',1,inplace=True)
hockey.head()
# Out:
#    hour                                            tweet_1     team
# 0    15   time retweet and follow to enter if buch scor...    [nyr]
# 1    15  which canadiens are untouchable beside mete price   [habs]
# 2    15                                lets do that hockey   [wild]
# 3    15                                 ed friggin belfour  [stars]
# 4    15             happy birthday ryan grim reaper reaves   [pens]

# %%
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])iswell(?![a-z])', 'is well')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fckity(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])miaminc(?![a-z])', 'miami inc')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])whre(?![a-z])', 'where')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cityyyy(?![a-z])', 'city')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cryincat(?![a-z])', 'crying cat')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mmhmm(?![a-z])', 'yeah')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])icingot(?![a-z])', 'icing overtime')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])interferedbut(?![a-z])', 'interfered but')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])rightrefs(?![a-z])', 'right refs')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cheapie(?![a-z])', 'cheap')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])jst(?![a-z])', 'just')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])eerrrrrr(?![a-z])', 'mad')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])enjoi(?![a-z])', 'enjoy')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])whatits(?![a-z])', 'what its')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])handfeeding(?![a-z])', 'hand feeding')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bathroomgetting(?![a-z])', 'bathroom getting')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])etrange(?![a-z])', 'estrange')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gamehence(?![a-z])', 'game hence')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mustve(?![a-z])', 'must have')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])capslets(?![a-z])', 'caps lets')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])roadtrips(?![a-z])', 'road trips')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])shite(?![a-z])', 'shit')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gamesthis(?![a-z])', 'game this')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])breakawayboeserstopped(?![a-z])', 'breakaway boeser stopped')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])yesand(?![a-z])', 'yes and')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])werk(?![a-z])', 'work')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])powlesland(?![a-z])', 'powles land')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ibut(?![a-z])', 'i but')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nashvilletn(?![a-z])', 'nashville tennessee')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])hellllll(?![a-z])', 'hell')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ownershipmanagement(?![a-z])', 'ownership management')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])anglevideo(?![a-z])', 'anglevideo')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gms(?![a-z])', 'games')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])yessssssss(?![a-z])', 'yes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])thejokerbrighton(?![a-z])', 'the joker brighton')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])teamates(?![a-z])', 'teammates')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])oooh(?![a-z])', 'oh')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lundqvistanchored(?![a-z])', 'lundqvist anchored')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nightperiod(?![a-z])', 'night period')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])icecouture(?![a-z])', 'ice couture')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bidh(?![a-z])', 'bid')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])unitit(?![a-z])', 'unit it')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])timingi(?![a-z])', 'timing i')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])seatsat(?![a-z])', 'seat sat')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fufill(?![a-z])', 'fulfill')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])opportunitiesgeez(?![a-z])', 'opportunities')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])thanthe(?![a-z])', 'than the')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])juicyyyyyyyyy(?![a-z])', 'juicy')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])eiration(?![a-z])', 'expiration')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])breakawaystopped(?![a-z])', 'breakaway stopped')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])dogfor(?![a-z])', 'dog for')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])noo(?![a-z])', 'no')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])embarassment(?![a-z])', 'embarrassment')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])icepound(?![a-z])', 'ice pound')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])topfive(?![a-z])', 'top five')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lostening(?![a-z])', 'listening')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])tonoilers(?![a-z])', 'ton oilers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])couponsspecialsmention(?![a-z])', 'coupons specials mention')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bestonbest(?![a-z])', 'best on best')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])flyerrrrrs(?![a-z])', 'flyers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gardinerget(?![a-z])', 'gardinerg et')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])outstrome(?![a-z])', 'out strome')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])changethis(?![a-z])', 'changethis')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])taipeizoo(?![a-z])', 'taipei zoo')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])meanr(?![a-z])', 'meaner')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])enquiries(?![a-z])', 'inquiries')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])camos(?![a-z])', 'camouflage')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])poolman(?![a-z])', 'pool man')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gmshfestdotcom(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])sometimesoften(?![a-z])', 'sometimes often')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gradeb(?![a-z])', 'graded')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mantough(?![a-z])', 'man tough')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])poolbbqfree(?![a-z])', 'pool barbeque free')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])penaltymove(?![a-z])', 'penalty move')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])scoreo(?![a-z])', 'score')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])calgaryflames(?![a-z])', 'calgary flames')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pms(?![a-z])', 'penalty minutes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])happend(?![a-z])', 'happened')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bleatingheres(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gamehow(?![a-z])', 'game how')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cya(?![a-z])', 'see you later')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])yeaaaaaaaaaa(?![a-z])', 'yeah')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gotbumped(?![a-z])', 'got bumped')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])assualtef(?![a-z])', 'assaulted')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])arizstlwe(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ohhh(?![a-z])', 'oh')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ommited(?![a-z])', 'ommitted')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])teamzero(?![a-z])', 'team zero')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])shotattempts(?![a-z])', 'shot attempts')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gameeeeeeeuhhhhh(?![a-z])', 'game')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])withthem(?![a-z])', 'with them')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])herskind(?![a-z])', 'hers kind')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])coachingfront(?![a-z])', 'coaching front')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])whaatsorry(?![a-z])', 'what sorry')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ponit(?![a-z])', 'point')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])laz(?![a-z])', 'lazy')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])backchecking(?![a-z])', 'back checking')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])brahhh(?![a-z])', 'dude')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])crrying(?![a-z])', 'crying')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])alreadyno(?![a-z])', 'already no')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])weakkneed(?![a-z])', 'weak kneed')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])rookienot(?![a-z])', 'rookie not')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])haaayes(?![a-z])', 'hayes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])sunlike(?![a-z])', 'sun like')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])remainsperlini(?![a-z])', 'remains perlini')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pianotime(?![a-z])', 'piano time')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])dooooooodes(?![a-z])', 'dudes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])devilsi(?![a-z])', 'devils')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])downtowwwwwwn(?![a-z])', 'downtown')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])playsyour(?![a-z])', 'plays your')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])icehogs(?![a-z])', 'ice hogs')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])onoff(?![a-z])', 'on off')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])softhawks(?![a-z])', 'soft hawks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])teamhigh(?![a-z])', 'team high')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])tweetsposts(?![a-z])', 'tweets posts')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fuuuuck(?![a-z])', 'fuck')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gilmoreget(?![a-z])', 'gilmore get')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mayfieldpulock(?![a-z])', 'mayfield pulock')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])webershaw(?![a-z])', 'weber shaw')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])draijplooch(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])hartnellunless(?![a-z])', 'hartnell unless')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])revitalised(?![a-z])', 'revitalized')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])stipid(?![a-z])', 'stupid')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pseudopowerplay(?![a-z])', 'pseudo power play')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mebuy(?![a-z])', 'me buy')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wearin(?![a-z])', 'wearing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])russias(?![a-z])', 'russians')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wgnradio(?![a-z])', 'wgn radio')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])torontoottawa(?![a-z])', 'toronto ottawa')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wwemma(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gamenight(?![a-z])', 'game night')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])handwringing(?![a-z])', 'hand wringing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])devildogs(?![a-z])', 'devil dogs')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])manadvantage(?![a-z])', 'man advantage')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bogglin(?![a-z])', 'boggling')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bigname(?![a-z])', 'big name')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])daynot(?![a-z])', 'day not')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])shouldve(?![a-z])', 'should have')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])frking(?![a-z])', 'fucking')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])liike(?![a-z])', 'like')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])homecan(?![a-z])', 'home can')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])slughorn(?![a-z])', 'slug horn')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])conf(?![a-z])', 'conference')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wingsday(?![a-z])', 'wings day')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pleeeeeeaaaase(?![a-z])', 'please')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ferlandmonahangaudreaumonahangoal(?![a-z])', 'ferland monahan gaudreau monahan goal')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])dancin(?![a-z])', 'dancing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])rigt(?![a-z])', 'right')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gamewinners(?![a-z])', 'game winners')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lifeif(?![a-z])', 'life if')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])newbornpuppy(?![a-z])', 'new born puppy')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])sighsame(?![a-z])', 'sighsame')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])chitb(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bargainbin(?![a-z])', 'bargain bin')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])postbye(?![a-z])', 'post bye')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nhlnhlpa(?![a-z])', 'national hockey league players association')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])suddendeath(?![a-z])', 'sudden death')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])scccooorrreeeee(?![a-z])', 'score')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])dmam(?![a-z])', 'defenseman')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])iterests(?![a-z])', 'interests')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fivepoint(?![a-z])', 'five point')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gametying(?![a-z])', 'game tying')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])jumpstart(?![a-z])', 'jump start')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])embarrasing(?![a-z])', 'embarrassing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])challengeannnnd(?![a-z])', 'challenge and')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])millgoal(?![a-z])', 'mill goal')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])muthereffin(?![a-z])', 'mother reffing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bitemojis(?![a-z])', 'bit emojis')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])placentiayorba(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])matchens(?![a-z])', 'matches')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])powerplay(?![a-z])', 'power play')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])reppin(?![a-z])', 'repping')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])teident(?![a-z])', 'trident')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('nyr', 'new york rangers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ana(?![a-z])', 'anaheim ducks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ari(?![a-z])', 'arizona coyotes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bos(?![a-z])', 'boston bruins')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])buf(?![a-z])', 'buffalo sabres')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])car(?![a-z])', 'carolina hurricanes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cgy(?![a-z])', 'calgary flames')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])chi(?![a-z])', 'chicago blackhawks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cbj(?![a-z])', 'columbus blue jackets')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])col(?![a-z])', 'colorado avalanche')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])dal(?![a-z])', 'dallas stars')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])det(?![a-z])', 'detroit red wings')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])edm(?![a-z])', 'edmonton oilers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fla(?![a-z])', 'florida panthers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lak(?![a-z])', 'los angeles kings')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])min(?![a-z])', 'minnesota wild')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('mtl', 'montreal canadiens')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nsh(?![a-z])', 'nashville predators')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('njd', 'new jersey devils')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('nyi', 'new york islanders')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ott(?![a-z])', 'ottawa senators')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])phi(?![a-z])', 'philadelphia flyers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pit(?![a-z])', 'pittsburgh penguins')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('sjs', 'san jose sharks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('stl', 'st. louis blues')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('tbl', 'tampa bay lightning')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])tor(?![a-z])', 'toronto maple leafs')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])van(?![a-z])', 'vancouver canucks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('vgk', 'vegas golden knights')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('wpg', 'winnipeg jets')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('wsh', 'washington capitals')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('redwings', 'red wings')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])winfographic(?![a-z])', 'infographic')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])besties(?![a-z])', 'best friends')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])confidencebuilding(?![a-z])', 'confidence building')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])ight(?![a-z])', 'all right')
hockey['tweet_1'] = hockey['tweet_1'].str.replace('penguinawarenessday', 'penguin awareness day')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])friggin(?![a-z])', '')

# %%
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gohabsgo(?![a-z])', 'go habs go')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])whatif(?![a-z])', 'what if')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])finenowif(?![a-z])', 'fine now if')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])leagueand(?![a-z])', 'league and')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wristah(?![a-z])', 'wrist shot')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])upagain(?![a-z])', 'up again')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])meetandgreet(?![a-z])', 'meet and greet')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])timesbonly(?![a-z])', 'times only')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])bagskated(?![a-z])', 'bag skated')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])capitallism(?![a-z])', 'capitalism')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])pppk(?![a-z])', 'power play penalty kill')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])diy(?![a-z])', 'do it yourself')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])gooooooood(?![a-z])', 'good')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])leftwing(?![a-z])', 'left wing')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])amptill(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])goingbut(?![a-z])', 'going but')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])whio(?![a-z])', 'who')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nobelprize(?![a-z])', 'nobel prize')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nobrainer(?![a-z])', 'no brainer')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])goooooooaaaaaaalllllll(?![a-z])', 'goal')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])jampacked(?![a-z])', 'jam packed')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])snipin(?![a-z])', 'sniping')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])schwag(?![a-z])', 'swag')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])vides(?![a-z])', 'videos')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])leavepretty(?![a-z])', 'leave pretty')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])combobet(?![a-z])', 'combo bet')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lazaranyone(?![a-z])', 'lazar anyone')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])aircraftand(?![a-z])', 'aircraft and')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wellhe(?![a-z])', 'well he')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])iceeeeeee(?![a-z])', 'ice')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])shotpuzzling(?![a-z])', 'shot puzzling')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])lmaooooo(?![a-z])', 'laugh my ass off')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])apparentlt(?![a-z])', 'apparently')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])mannn(?![a-z])', 'man')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])himjust(?![a-z])', 'him just')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])kidhes(?![a-z])', 'kid hes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])verrrrry(?![a-z])', 'very')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])cbusits(?![a-z])', 'columbus its')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])glovedrops(?![a-z])', 'glove drops')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])thankgod(?![a-z])', 'thank god')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])fustrations(?![a-z])', 'frustrations')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])nearcatastrophe(?![a-z])', 'near catastrophe')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])quackaheims(?![a-z])', '')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])wingsnorth(?![a-z])', 'wings north')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])zoneif(?![a-z])', 'zone if')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])promowest(?![a-z])', 'promo west')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@anaheimducks(?![a-z])', 'anaheim ducks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])#letsgoducks(?![a-z])', 'lets go ducks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@arizonacoyotes(?![a-z])', 'arizona coyotes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlbruins(?![a-z])', 'boston bruins')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@buffalosabres(?![a-z])', 'buffalo sabres')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlflames(?![a-z])', 'calgary flames')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])#cofred(?![a-z])', 'calgary flames')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlcanes(?![a-z])', 'carolina hurricanes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])#redvolution(?![a-z])', 'carolina hurricanes')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlblackhawks(?![a-z])', 'chicago blackhawks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@avalanche(?![a-z])', 'colorado avalanche')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@bluejacketsnhl(?![a-z])', 'columbus blue jackets')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])#cbj(?![a-z])', 'columbus blue jackets')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@dallasstars(?![a-z])', 'dallas stars')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])#gostars(?![a-z])', 'go stars')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@detroitredwings(?![a-z])', 'detroit red wings')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@edmontonoilers(?![a-z])', 'edmonton oilers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@flapanthers(?![a-z])', 'florida panthers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@lakings(?![a-z])', 'los angeles kings')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@mnwild(?![a-z])', 'minnesota wild')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@canadiensmtl(?![a-z])', 'montreal canadiens')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@predsnhl(?![a-z])', 'nashville predators')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@njdevils(?![a-z])', 'new jersey devils')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nyislanders(?![a-z])', 'new york islanders')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@senators(?![a-z])', 'ottawa senators')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlflyers(?![a-z])', 'philadelphia flyers')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@penguins(?![a-z])', 'pittsburgh penguins')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@sanjosesharks(?![a-z])', 'san jose sharks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@stlouisblues(?![a-z])', 'st louis blues')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@tblightning(?![a-z])', 'tampa bay lightning')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@mapleleafs(?![a-z])', 'toronto maple leafs')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@canucks(?![a-z])', 'vancouver canucks')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@goldenknights(?![a-z])', 'vegas golden knights')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@capitals(?![a-z])', 'washington capitals')
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])@nhlets(?![a-z])', 'winnipeg jets')

# %%
hockey['tweet_1'] = hockey['tweet_1'].str.replace(r'(?<![a-z])jokeso(?![a-z])', 'joke so')

# %%
hockey.head(10)
# Out:
#    hour                                            tweet_1      team
# 0    15   time retweet and follow to enter if buch scor...     [nyr]
# 1    15  which canadiens are untouchable beside mete price    [habs]
# 2    15                                lets do that hockey    [wild]
# 3    15                                        ed  belfour   [stars]
# 4    15             happy birthday ryan grim reaper reaves    [pens]
# 5    15  a big weekend for minnesota sport fans today i...    [wild]
# 6    15  the learn to play program is back this season ...    [habs]
# 7    15       happy to the best penguins fans we know cred    [pens]
# 8    15  g  canucks at oilers the first saturday withou...  [oilers]
# 9    15  its game day  avalanche colorado   pm pregame ...     [nyr]

# %%
hockey = hockey.drop('hour', 1)

# %%
hockey.to_csv('additional_corrections.csv')
